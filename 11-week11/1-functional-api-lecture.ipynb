# %% [markdown]
# # More Complex Models with the Functional API
#
# Although the Sequential API in Keras is quite straightforward and Sequential models are quite common, it is sometime useful to build networks with more complex topologies, or multiple inputs or outputs. The Keras Functional API provides a more flexible way to define models that makes this possible. It is particularly useful for models with non-linear topology, shared layers, or multiple inputs/outputs.
#
# In this lecture, we'll delve into the Functional API with a focus on building a ["Wide & Deep" network](https://ai.google/research/pubs/pub45413), a model architecture that can manage both deep and wide feature learning effectively.
#
# #### When to Use the Functional API
#
# - **Model Complexity:** The Functional API is ideal when dealing with complex model architectures, such as those requiring multiple input and output layers, shared layers, or residual connections.
# - **Flexibility:** It allows for more customization and control over your model architecture. Unlike the Sequential API, where layers are stacked linearly, the Functional API enables you to define more complex and non-linear relationships.
# - **Research and Experimentation:** If you're experimenting with novel architectures or conducting research, the Functional API allows for more experimental flexibility.
#
# ## Designing a Wide & Deep Network for More Complex Data
#
# The "Wide & Deep" learning model, conceptualized by Google, is designed to effectively harness both linear and non-linear feature representations. Understanding why and how this model works involves delving into the strengths of its two components: the "wide" part for linear aspects and the "deep" part for complex relationships.
#
# <div style="text-align:center">
#
# ![wide and deep nn](assets/wide_and_deep.png)
#
# </div>
#
# #### The "Wide" Component
#
# - **Linear Relationships:**
#   - The wide part of the model is designed to learn linear relationships. This means it's good at memorizing or managing sparse data and feature interactions.
#   - In practice, this often translates to a form of logistic regression or linear regression, depending on the task.
#
# - **Feature Interactions:**
#   - The wide component can effectively capture simple rules and interactions between features. For instance, if certain feature combinations are particularly predictive of the target variable, the wide component can learn this directly.
#
# - **Advantage in Memorization:**
#   - The wide part excels in memorization, which is beneficial for learning from sparse data where certain feature combinations may be very predictive but don't occur frequently enough for a deep model to learn and generalize. Categorical features, especially those with a large number of possible values, often work well with the wide part.
#
# #### The "Deep" Component
#
# - **Complex Relationships:**
#   - The deep component, typically a deep neural network, is adept at learning complex, non-linear relationships and feature hierarchies.
#   - These networks automatically learn to represent data in a hierarchical fashion (low-level features in early layers, more abstract features in deeper layers).
#
# - **Generalization:**
#   - Deep networks are particularly good at generalizing to new scenarios. They can infer unseen relationships based on the hierarchies they've learned, making them powerful for tasks involving unstructured data like images and text.
#
# - **Feature Learning:**
#   - Unlike the wide part, deep networks don't require explicit feature engineering. They can automatically learn useful representations from raw data, making them highly versatile and adaptable. Numerical features, particularly those that require complex transformations to relate to the output, are suitable for the deep part.
#
#
# The Wide & Deep model combines the strengths of memorization and generalization. Use the wide part for features where the relationship with the output is expected to be linear or rule-based, and the deep part for more abstract patterns and relationships. For example, in a recommendation system, the wide part can effectively capture specific user-item interactions (like a particular user's preference for a specific genre), while the deep part can learn user preferences and item characteristics from user and item metadata.
#
# When designing a Wide & Deep model, balance is key. Overemphasizing the wide part might lead to overfitting on specific feature combinations, while focusing too much on the deep part might result in missing out on simple, predictive rules in the data. The optimal balance often depends on the specific nature of the dataset and the problem.
#
# ## Implementing a Wide & Deep Network
#
# We'll develop a Wide & Deep Network to tackle the [California Housing dataset](https://developers.google.com/machine-learning/crash-course/california-housing-data-description). The dataset includes a mix of features, some of which have a clear linear relationship with the target variable, while others may have more complex, non-linear relationships.  For example, features like 'median income' might have a more straightforward, linear relationship with housing prices. In contrast, features like 'latitude' and 'longitude' could have a non-linear and more complex interaction with the price.
#
# Our goal here is to predict the median house price for each "block group."
#
# #### Retrieving the data

# %%
import tensorflow as tf
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

# %%
housing = fetch_california_housing()
X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, random_state=42)
# Reserve an item for prediction
X_new = X_test[:3]

# %%
print(housing.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block group
#         - HouseAge      median house age in block group
#         - AveRooms      average number of rooms per household
#         - AveBedrms     average number of bedrooms per household
#         - Population    block group population
#         - AveOccup      average number of household members
#         - Latitude      block group latitude
#         - Longitude     block group longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# An household is a group of people residing within a home. Since the average
# number of rooms and bedrooms in this dataset are provided per household, these
# columns may take surpinsingly large values for block groups with few households
# and many empty houses, such as vacation resorts.
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297

# %%
import numpy as np
# Note that outputs are in $100,000
print(f"Min {np.min(y_train_full)} - Max {np.max(y_train_full)}")
# Out:
# Min 0.14999 - Max 5.00001

# %% [markdown]
# #### Setting up the model

# %%
# extra code – reset the name counters and make the code reproducible
tf.keras.backend.clear_session()
tf.random.set_seed(42)

# Normalization layer to standardize the inputs,, , and one more Dense layer with a single neuron for the output layer, without any activation function
normalization_layer = tf.keras.layers.Normalization()

# two Dense layers with 30 neurons each, using the ReLU activation function
hidden_layer1 = tf.keras.layers.Dense(30, activation="relu")
hidden_layer2 = tf.keras.layers.Dense(30, activation="relu")

#Concatenate layer - In a Wide & Deep network, you have two paths: the wide path (simple linear relationships) 
#and the deep path (complex non-linear relationships). The concatenate layer is used to merge these two paths. 
#It takes outputs from both the wide and deep components and concatenates them along a specified axis (by default, the last axis).
concat_layer = tf.keras.layers.Concatenate()

#Dense layer with a single neuron for the output layer, without any activation function.  This is the median housing price.
output_layer = tf.keras.layers.Dense(1)

# The Input object (the variable name input_ is used to avoid overshadowing Python’s built-in input() function). 
# This is a specification of the kind of input the model 
# will get, including its shape and optionally its dtype, which defaults to 32-bit floats. 
# A model may actually have multiple inputs, as you will see shortly.
input_ = tf.keras.layers.Input(shape=X_train.shape[1:])


#Normalization layer just like a function, passing it the Input object. This is why this is called the functional API. 
# Note that we are just telling Keras how it should connect the layers together; no actual data is being processed yet, 
# as the Input object is just a data specification. In other words, it’s a symbolic input. The output of this call is 
# also symbolic: normalized doesn’t store any actual data, it’s just used to construct the model.
normalized = normalization_layer(input_)

# In the same way, we then pass normalized to hidden_layer1, which outputs hidden1, 
# and we pass hidden1 to hidden_layer2, which outputs hidden2.
hidden1 = hidden_layer1(normalized)
hidden2 = hidden_layer2(hidden1)

#So far we’ve connected the layers sequentially, but then we use the concat_layer to 
# concatenate the input and the second hidden layer’s output. Again, no actual data is 
# concatenated yet: it’s all symbolic, to build the model.
concat = concat_layer([normalized, hidden2])

# Then we pass concat to the output_layer, which gives us the final output.
output = output_layer(concat)

# Finally create the model, specifying inputs and outputs
model = tf.keras.Model(inputs=[input_], outputs=[output])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 8)]                  0         []
#
#  normalization (Normalizati  (None, 8)                    17        ['input_1[0][0]']
#  on)
#
#  dense (Dense)               (None, 30)                   270       ['normalization[0][0]']
#
#  dense_1 (Dense)             (None, 30)                   930       ['dense[0][0]']
#
#  concatenate (Concatenate)   (None, 38)                   0         ['normalization[0][0]',
#                                                                      'dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    39        ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 1256 (4.91 KB)
# Trainable params: 1239 (4.84 KB)
# Non-trainable params: 17 (72.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# Once again, we compile and train the model, just like before...

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="mse", optimizer=optimizer, metrics=["RootMeanSquaredError"])

# This is necessary in order to make sure the normalization layer correctly calculate things like the mean and 
# standard deviation necessary
normalization_layer.adapt(X_train)
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
mse_test = model.evaluate(X_test, y_test)
y_pred = model.predict(X_new)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/20
# 363/363 [==============================] - 1s 1ms/step - loss: 1.2884 - root_mean_squared_error: 1.1351 - val_loss: 2.4972 - val_root_mean_squared_error: 1.5802
# Epoch 2/20
# 363/363 [==============================] - 0s 844us/step - loss: 0.4678 - root_mean_squared_error: 0.6840 - val_loss: 0.6590 - val_root_mean_squared_error: 0.8118
# Epoch 3/20
# 363/363 [==============================] - 0s 897us/step - loss: 0.4018 - root_mean_squared_error: 0.6339 - val_loss: 0.4387 - val_root_mean_squared_error: 0.6623
# Epoch 4/20
# 363/363 [==============================] - 0s 830us/step - loss: 0.3841 - root_mean_squared_error: 0.6198 - val_loss: 0.3721 - val_root_mean_squared_error: 0.6100
# Epoch 5/20
# 363/363 [==============================] - 0s 848us/step - loss: 0.3731 - root_mean_squared_error: 0.6108 - val_loss: 0.3590 - val_root_mean_squared_error: 0.5992
# Epoch 6/20
# 363/363 [==============================] - 0s 821us/step - loss: 0.3620 - root_mean_squared_error: 0.6016 - val_loss: 0.4143 - val_root_mean_squared_error: 0.6437
# Epoch 7/20
# 363/363 [==============================] - 0s 811us/step - loss: 0.3602 - root_mean_squared_error: 0.6001 - val_loss: 0.6706 - val_root_mean_squared_error: 0.8189
# Epoch 8/20
# 363/363 [==============================] - 0s 828us/step - loss: 0.3483 - root_mean_squared_error: 0.5902 - val_loss: 0.9989 - val_root_mean_squared_error: 0.9994
# Epoch 9/20
# 363/363 [==============================] - 0s 820us/step - loss: 0.3445 - root_mean_squared_error: 0.5870 - val_loss: 1.2021 - val_root_mean_squared_error: 1.0964
# Epoch 10/20
# 363/363 [==============================] - 0s 809us/step - loss: 0.3463 - root_mean_squared_error: 0.5885 - val_loss: 2.3059 - val_root_mean_squared_error: 1.5185
# Epoch 11/20
# 363/363 [==============================] - 0s 808us/step - loss: 0.3382 - root_mean_squared_error: 0.5816 - val_loss: 0.7559 - val_root_mean_squared_error: 0.8694
# Epoch 12/20
# 363/363 [==============================] - 0s 792us/step - loss: 0.3480 - root_mean_squared_error: 0.5899 - val_loss: 1.5333 - val_root_mean_squared_error: 1.2383
# Epoch 13/20
# 363/363 [==============================] - 0s 788us/step - loss: 0.3290 - root_mean_squared_error: 0.5736 - val_loss: 0.4076 - val_root_mean_squared_error: 0.6384
# Epoch 14/20
# 363/363 [==============================] - 0s 789us/step - loss: 0.3163 - root_mean_squared_error: 0.5624 - val_loss: 0.4303 - val_root_mean_squared_error: 0.6559
# Epoch 15/20
# 363/363 [==============================] - 0s 793us/step - loss: 0.3153 - root_mean_squared_error: 0.5615 - val_loss: 0.3544 - val_root_mean_squared_error: 0.5953
# Epoch 16/20
# 363/363 [==============================] - 0s 784us/step - loss: 0.3108 - root_mean_squared_error: 0.5575 - val_loss: 0.3563 - val_root_mean_squared_error: 0.5969
# Epoch 17/20
# 363/363 [==============================] - 0s 811us/step - loss: 0.3098 - root_mean_squared_error: 0.5566 - val_loss: 0.3554 - val_root_mean_squared_error: 0.5961
# Epoch 18/20
# 363/363 [==============================] - 0s 793us/step - loss: 0.3065 - root_mean_squared_error: 0.5536 - val_loss: 1.4809 - val_root_mean_squared_error: 1.2169
# Epoch 19/20
# 363/363 [==============================] - 0s 792us/step - loss: 0.3115 - root_mean_squared_error: 0.5581 - val_loss: 2.0253 - val_root_mean_squared_error: 1.4231
# Epoch 20/20
# 363/363 [==============================] - 0s 797us/step - loss: 0.3261 - root_mean_squared_error: 0.5711 - val_loss: 1.7778 - val_root_mean_squared_error: 1.3334
# 162/162 [==============================] - 0s 486us/step - loss: 0.3161 - root_mean_squared_error: 0.5622
# 1/1 [==============================] - 0s 55ms/step

# %%
import matplotlib.pyplot as plt
import pandas as pd

pd.DataFrame(history.history).plot(
    figsize=(8, 5), xlim=[0, 20], ylim=[0, 2], grid=True, xlabel="Epoch",
    style=["r--", "r--.", "b-", "b-*"])
plt.legend(loc="lower left")  # extra code
plt.show()

# %% [markdown]
# Yikes!  Note that an RMS error of 1 (roughly our mean validation error) is $100,000, which isn't great.
#
# There are a few things we might try.  First, we might consider splitting our features, so that the "wide" and "deep" part of the network focus on different subsets of features.  For example, we might send the first five features through the wide path (based on the assumption that these should have a linear relationship with price) and the last six features through the deep path (assuming a more complex relationship here). Note that this is how we can use our domain knowledge to construct a network!
#
# The envisioned network looks something like:
#
# <div style="text-align:center">
#
# ![Wide and deep 2](assets/wide_and_deep2.png)
#
# </div>

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)

input_wide = tf.keras.layers.Input(shape=[5]) # features 0 to 4 
input_deep = tf.keras.layers.Input(shape=[6]) # features 2 to 7 
norm_layer_wide = tf.keras.layers.Normalization() 
norm_layer_deep = tf.keras.layers.Normalization()
norm_wide = norm_layer_wide(input_wide)
norm_deep = norm_layer_deep(input_deep)

# Note, the following is just a shorthand where we construct and then attach the network all in one go
hidden1 = tf.keras.layers.Dense(30, activation="relu")(norm_deep)
hidden2 = tf.keras.layers.Dense(30, activation="relu")(hidden1)
concat = tf.keras.layers.concatenate([norm_wide, hidden2])
output = tf.keras.layers.Dense(1)(concat)
model = tf.keras.Model(inputs=[input_wide, input_deep], outputs=[output])

# %% [markdown]
# Now we compile as usual, but we need to pass a pair of matrices in order to align with the expected input, and similarly with the validation and test data.

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="mse", optimizer=optimizer, metrics=["RootMeanSquaredError"])

# Note the offsets are used here to split up the features according to our input layer
X_train_wide, X_train_deep = X_train[:, :5], X_train[:, 2:] 
X_valid_wide, X_valid_deep = X_valid[:, :5], X_valid[:, 2:] 
X_test_wide, X_test_deep = X_test[:, :5], X_test[:, 2:] 
X_new_wide, X_new_deep = X_test_wide[:3], X_test_deep[:3]


norm_layer_wide.adapt(X_train_wide) 
norm_layer_deep.adapt(X_train_deep)

history = model.fit((X_train_wide, X_train_deep), y_train, epochs=20, validation_data=((X_valid_wide, X_valid_deep), y_valid)) 
mse_test = model.evaluate((X_test_wide, X_test_deep), y_test)
y_pred = model.predict((X_new_wide, X_new_deep))
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/20
# 363/363 [==============================] - 1s 1ms/step - loss: 1.2219 - root_mean_squared_error: 1.1054 - val_loss: 0.5436 - val_root_mean_squared_error: 0.7373
# Epoch 2/20
# 363/363 [==============================] - 0s 822us/step - loss: 0.4755 - root_mean_squared_error: 0.6896 - val_loss: 0.5680 - val_root_mean_squared_error: 0.7536
# Epoch 3/20
# 363/363 [==============================] - 0s 820us/step - loss: 0.4340 - root_mean_squared_error: 0.6588 - val_loss: 0.3952 - val_root_mean_squared_error: 0.6287
# Epoch 4/20
# 363/363 [==============================] - 0s 822us/step - loss: 0.4033 - root_mean_squared_error: 0.6351 - val_loss: 0.4768 - val_root_mean_squared_error: 0.6905
# Epoch 5/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3913 - root_mean_squared_error: 0.6255 - val_loss: 0.3648 - val_root_mean_squared_error: 0.6040
# Epoch 6/20
# 363/363 [==============================] - 0s 819us/step - loss: 0.3731 - root_mean_squared_error: 0.6109 - val_loss: 0.4643 - val_root_mean_squared_error: 0.6814
# Epoch 7/20
# 363/363 [==============================] - 0s 821us/step - loss: 0.3712 - root_mean_squared_error: 0.6093 - val_loss: 0.7400 - val_root_mean_squared_error: 0.8603
# Epoch 8/20
# 363/363 [==============================] - 0s 819us/step - loss: 0.3608 - root_mean_squared_error: 0.6007 - val_loss: 0.5561 - val_root_mean_squared_error: 0.7457
# Epoch 9/20
# 363/363 [==============================] - 0s 818us/step - loss: 0.3567 - root_mean_squared_error: 0.5972 - val_loss: 1.1641 - val_root_mean_squared_error: 1.0789
# Epoch 10/20
# 363/363 [==============================] - 0s 818us/step - loss: 0.3603 - root_mean_squared_error: 0.6003 - val_loss: 1.3187 - val_root_mean_squared_error: 1.1483
# Epoch 11/20
# 363/363 [==============================] - 0s 823us/step - loss: 0.3513 - root_mean_squared_error: 0.5927 - val_loss: 0.3745 - val_root_mean_squared_error: 0.6120
# Epoch 12/20
# 363/363 [==============================] - 0s 832us/step - loss: 0.3536 - root_mean_squared_error: 0.5947 - val_loss: 0.6063 - val_root_mean_squared_error: 0.7786
# Epoch 13/20
# 363/363 [==============================] - 0s 822us/step - loss: 0.3450 - root_mean_squared_error: 0.5874 - val_loss: 0.3878 - val_root_mean_squared_error: 0.6227
# Epoch 14/20
# 363/363 [==============================] - 0s 820us/step - loss: 0.3380 - root_mean_squared_error: 0.5814 - val_loss: 0.3266 - val_root_mean_squared_error: 0.5715
# Epoch 15/20
# 363/363 [==============================] - 0s 817us/step - loss: 0.3405 - root_mean_squared_error: 0.5835 - val_loss: 0.5062 - val_root_mean_squared_error: 0.7114
# Epoch 16/20
# 363/363 [==============================] - 0s 951us/step - loss: 0.3336 - root_mean_squared_error: 0.5775 - val_loss: 0.3605 - val_root_mean_squared_error: 0.6004
# Epoch 17/20
# 363/363 [==============================] - 0s 821us/step - loss: 0.3335 - root_mean_squared_error: 0.5775 - val_loss: 0.4023 - val_root_mean_squared_error: 0.6343
# Epoch 18/20
# 363/363 [==============================] - 0s 819us/step - loss: 0.3287 - root_mean_squared_error: 0.5733 - val_loss: 0.9411 - val_root_mean_squared_error: 0.9701
# Epoch 19/20
# 363/363 [==============================] - 0s 831us/step - loss: 0.3322 - root_mean_squared_error: 0.5764 - val_loss: 1.1445 - val_root_mean_squared_error: 1.0698
# Epoch 20/20
# 363/363 [==============================] - 0s 819us/step - loss: 0.3362 - root_mean_squared_error: 0.5798 - val_loss: 0.6559 - val_root_mean_squared_error: 0.8099
# 162/162 [==============================] - 0s 516us/step - loss: 0.3266 - root_mean_squared_error: 0.5715
# 1/1 [==============================] - 0s 44ms/step

# %%
import matplotlib.pyplot as plt
import pandas as pd

pd.DataFrame(history.history).plot(
    figsize=(8, 5), xlim=[0, 20], ylim=[0, 2], grid=True, xlabel="Epoch",
    style=["r--", "r--.", "b-", "b-*"])
plt.legend(loc="lower left")  # extra code
plt.show()

# %% [markdown]
# Yikes! Another thing we can try here is to give the hidden layers an explicit training signal in order to force them to learn something directly about the data.  This is a type of regularization, because it helps to constrain the hidden layers so that they are not simply "memorizing" the data.  Our new architecture would look something like:
#
# <div style="text-align: center">
#
# ![Wide and deep 3](assets/wide_and_deep3.png)
#
# </div>
#
# Our auxiliary output requires is own loss function, but these two losses are combined during training.  Keras allows us to specify a weighting that will allow us to control the relative importance of these two losses.

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)

input_wide = tf.keras.layers.Input(shape=[5])  # features 0 to 4
input_deep = tf.keras.layers.Input(shape=[6])  # features 2 to 7
norm_layer_wide = tf.keras.layers.Normalization()
norm_layer_deep = tf.keras.layers.Normalization()
norm_wide = norm_layer_wide(input_wide)
norm_deep = norm_layer_deep(input_deep)
hidden1 = tf.keras.layers.Dense(30, activation="relu")(norm_deep)
hidden2 = tf.keras.layers.Dense(30, activation="relu")(hidden1)
concat = tf.keras.layers.concatenate([norm_wide, hidden2])
output = tf.keras.layers.Dense(1)(concat)
aux_output = tf.keras.layers.Dense(1)(hidden2)
model = tf.keras.Model(inputs=[input_wide, input_deep],
                       outputs=[output, aux_output])

# %% [markdown]
# Now we compile model and specify the different loss functions.

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss=("mse", "mse"), loss_weights=(0.9, 0.1), optimizer=optimizer,
              metrics=["RootMeanSquaredError"])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# Now, training, being sure to specify the output labels for both output layers.

# %%
# Remember to adapt the normalization layers!!!
norm_layer_wide.adapt(X_train_wide)
norm_layer_deep.adapt(X_train_deep)
history = model.fit(
    (X_train_wide, X_train_deep), (y_train, y_train), epochs=20,
    validation_data=((X_valid_wide, X_valid_deep), (y_valid, y_valid))
)
# Out:
# Epoch 1/20
# 363/363 [==============================] - 1s 1ms/step - loss: 1.3625 - dense_2_loss: 1.2760 - dense_3_loss: 2.1407 - dense_2_root_mean_squared_error: 1.1296 - dense_3_root_mean_squared_error: 1.4631 - val_loss: 1.0013 - val_dense_2_loss: 0.5220 - val_dense_3_loss: 5.3150 - val_dense_2_root_mean_squared_error: 0.7225 - val_dense_3_root_mean_squared_error: 2.3054
# Epoch 2/20
# 363/363 [==============================] - 0s 959us/step - loss: 0.4857 - dense_2_loss: 0.4541 - dense_3_loss: 0.7695 - dense_2_root_mean_squared_error: 0.6739 - dense_3_root_mean_squared_error: 0.8772 - val_loss: 1.5970 - val_dense_2_loss: 1.4941 - val_dense_3_loss: 2.5235 - val_dense_2_root_mean_squared_error: 1.2223 - val_dense_3_root_mean_squared_error: 1.5885
# Epoch 3/20
# 363/363 [==============================] - 0s 949us/step - loss: 0.4419 - dense_2_loss: 0.4239 - dense_3_loss: 0.6040 - dense_2_root_mean_squared_error: 0.6510 - dense_3_root_mean_squared_error: 0.7772 - val_loss: 0.4686 - val_dense_2_loss: 0.3930 - val_dense_3_loss: 1.1492 - val_dense_2_root_mean_squared_error: 0.6269 - val_dense_3_root_mean_squared_error: 1.0720
# Epoch 4/20
# 363/363 [==============================] - 0s 951us/step - loss: 0.4074 - dense_2_loss: 0.3919 - dense_3_loss: 0.5471 - dense_2_root_mean_squared_error: 0.6260 - dense_3_root_mean_squared_error: 0.7397 - val_loss: 0.5052 - val_dense_2_loss: 0.4614 - val_dense_3_loss: 0.8996 - val_dense_2_root_mean_squared_error: 0.6792 - val_dense_3_root_mean_squared_error: 0.9485
# Epoch 5/20
# 363/363 [==============================] - 0s 951us/step - loss: 0.3952 - dense_2_loss: 0.3820 - dense_3_loss: 0.5145 - dense_2_root_mean_squared_error: 0.6180 - dense_3_root_mean_squared_error: 0.7173 - val_loss: 0.8071 - val_dense_2_loss: 0.8430 - val_dense_3_loss: 0.4834 - val_dense_2_root_mean_squared_error: 0.9182 - val_dense_3_root_mean_squared_error: 0.6952
# Epoch 6/20
# 363/363 [==============================] - 0s 961us/step - loss: 0.3843 - dense_2_loss: 0.3731 - dense_3_loss: 0.4855 - dense_2_root_mean_squared_error: 0.6108 - dense_3_root_mean_squared_error: 0.6968 - val_loss: 1.4995 - val_dense_2_loss: 1.5651 - val_dense_3_loss: 0.9097 - val_dense_2_root_mean_squared_error: 1.2510 - val_dense_3_root_mean_squared_error: 0.9538
# Epoch 7/20
# 363/363 [==============================] - 0s 957us/step - loss: 0.3841 - dense_2_loss: 0.3742 - dense_3_loss: 0.4734 - dense_2_root_mean_squared_error: 0.6117 - dense_3_root_mean_squared_error: 0.6880 - val_loss: 1.4835 - val_dense_2_loss: 1.5983 - val_dense_3_loss: 0.4497 - val_dense_2_root_mean_squared_error: 1.2643 - val_dense_3_root_mean_squared_error: 0.6706
# Epoch 8/20
# 363/363 [==============================] - 0s 950us/step - loss: 0.3710 - dense_2_loss: 0.3618 - dense_3_loss: 0.4530 - dense_2_root_mean_squared_error: 0.6015 - dense_3_root_mean_squared_error: 0.6730 - val_loss: 4.1520 - val_dense_2_loss: 4.2193 - val_dense_3_loss: 3.5467 - val_dense_2_root_mean_squared_error: 2.0541 - val_dense_3_root_mean_squared_error: 1.8833
# Epoch 9/20
# 363/363 [==============================] - 0s 953us/step - loss: 0.3791 - dense_2_loss: 0.3702 - dense_3_loss: 0.4592 - dense_2_root_mean_squared_error: 0.6084 - dense_3_root_mean_squared_error: 0.6776 - val_loss: 2.6126 - val_dense_2_loss: 2.7636 - val_dense_3_loss: 1.2538 - val_dense_2_root_mean_squared_error: 1.6624 - val_dense_3_root_mean_squared_error: 1.1197
# Epoch 10/20
# 363/363 [==============================] - 0s 953us/step - loss: 0.3808 - dense_2_loss: 0.3734 - dense_3_loss: 0.4478 - dense_2_root_mean_squared_error: 0.6110 - dense_3_root_mean_squared_error: 0.6692 - val_loss: 1.0942 - val_dense_2_loss: 1.1005 - val_dense_3_loss: 1.0379 - val_dense_2_root_mean_squared_error: 1.0491 - val_dense_3_root_mean_squared_error: 1.0188
# Epoch 11/20
# 363/363 [==============================] - 0s 955us/step - loss: 0.3572 - dense_2_loss: 0.3491 - dense_3_loss: 0.4300 - dense_2_root_mean_squared_error: 0.5909 - dense_3_root_mean_squared_error: 0.6558 - val_loss: 0.3423 - val_dense_2_loss: 0.3335 - val_dense_3_loss: 0.4208 - val_dense_2_root_mean_squared_error: 0.5775 - val_dense_3_root_mean_squared_error: 0.6487
# Epoch 12/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3546 - dense_2_loss: 0.3467 - dense_3_loss: 0.4261 - dense_2_root_mean_squared_error: 0.5888 - dense_3_root_mean_squared_error: 0.6527 - val_loss: 0.6106 - val_dense_2_loss: 0.6051 - val_dense_3_loss: 0.6603 - val_dense_2_root_mean_squared_error: 0.7779 - val_dense_3_root_mean_squared_error: 0.8126
# Epoch 13/20
# 363/363 [==============================] - 0s 949us/step - loss: 0.3510 - dense_2_loss: 0.3431 - dense_3_loss: 0.4221 - dense_2_root_mean_squared_error: 0.5857 - dense_3_root_mean_squared_error: 0.6497 - val_loss: 0.3686 - val_dense_2_loss: 0.3632 - val_dense_3_loss: 0.4171 - val_dense_2_root_mean_squared_error: 0.6027 - val_dense_3_root_mean_squared_error: 0.6459
# Epoch 14/20
# 363/363 [==============================] - 0s 953us/step - loss: 0.3481 - dense_2_loss: 0.3403 - dense_3_loss: 0.4188 - dense_2_root_mean_squared_error: 0.5833 - dense_3_root_mean_squared_error: 0.6471 - val_loss: 0.3384 - val_dense_2_loss: 0.3220 - val_dense_3_loss: 0.4856 - val_dense_2_root_mean_squared_error: 0.5675 - val_dense_3_root_mean_squared_error: 0.6968
# Epoch 15/20
# 363/363 [==============================] - 0s 953us/step - loss: 0.3446 - dense_2_loss: 0.3373 - dense_3_loss: 0.4103 - dense_2_root_mean_squared_error: 0.5807 - dense_3_root_mean_squared_error: 0.6405 - val_loss: 0.4721 - val_dense_2_loss: 0.4760 - val_dense_3_loss: 0.4366 - val_dense_2_root_mean_squared_error: 0.6899 - val_dense_3_root_mean_squared_error: 0.6607
# Epoch 16/20
# 363/363 [==============================] - 0s 951us/step - loss: 0.3413 - dense_2_loss: 0.3341 - dense_3_loss: 0.4062 - dense_2_root_mean_squared_error: 0.5780 - dense_3_root_mean_squared_error: 0.6373 - val_loss: 0.5027 - val_dense_2_loss: 0.4785 - val_dense_3_loss: 0.7208 - val_dense_2_root_mean_squared_error: 0.6917 - val_dense_3_root_mean_squared_error: 0.8490
# Epoch 17/20
# 363/363 [==============================] - 0s 952us/step - loss: 0.3426 - dense_2_loss: 0.3356 - dense_3_loss: 0.4058 - dense_2_root_mean_squared_error: 0.5793 - dense_3_root_mean_squared_error: 0.6370 - val_loss: 0.6069 - val_dense_2_loss: 0.6210 - val_dense_3_loss: 0.4801 - val_dense_2_root_mean_squared_error: 0.7880 - val_dense_3_root_mean_squared_error: 0.6929
# Epoch 18/20
# 363/363 [==============================] - 0s 965us/step - loss: 0.3380 - dense_2_loss: 0.3312 - dense_3_loss: 0.3995 - dense_2_root_mean_squared_error: 0.5755 - dense_3_root_mean_squared_error: 0.6321 - val_loss: 2.1884 - val_dense_2_loss: 2.1706 - val_dense_3_loss: 2.3484 - val_dense_2_root_mean_squared_error: 1.4733 - val_dense_3_root_mean_squared_error: 1.5325
# Epoch 19/20
# 363/363 [==============================] - 0s 954us/step - loss: 0.3484 - dense_2_loss: 0.3418 - dense_3_loss: 0.4077 - dense_2_root_mean_squared_error: 0.5846 - dense_3_root_mean_squared_error: 0.6385 - val_loss: 1.9910 - val_dense_2_loss: 2.1120 - val_dense_3_loss: 0.9018 - val_dense_2_root_mean_squared_error: 1.4533 - val_dense_3_root_mean_squared_error: 0.9496
# Epoch 20/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3505 - dense_2_loss: 0.3452 - dense_3_loss: 0.3979 - dense_2_root_mean_squared_error: 0.5875 - dense_3_root_mean_squared_error: 0.6308 - val_loss: 0.9062 - val_dense_2_loss: 0.9212 - val_dense_3_loss: 0.7707 - val_dense_2_root_mean_squared_error: 0.9598 - val_dense_3_root_mean_squared_error: 0.8779

# %%
eval_results = model.evaluate((X_test_wide, X_test_deep), (y_test, y_test))
weighted_sum_of_losses, main_loss, aux_loss, main_rmse, aux_rmse = eval_results
print(f"""
Weighed Sum of Losses: {weighted_sum_of_losses}
Main Loss: {main_loss}
Aux Loss: {aux_loss}
Main RMSE: {main_rmse}
Aux RMSE: {aux_rmse}
      """)
# Out:
# 162/162 [==============================] - 0s 600us/step - loss: 0.3396 - dense_2_loss: 0.3333 - dense_3_loss: 0.3966 - dense_2_root_mean_squared_error: 0.5773 - dense_3_root_mean_squared_error: 0.6297
#
# Weighed Sum of Losses: 0.33960476517677307
# Main Loss: 0.33327725529670715
# Aux Loss: 0.3965524137020111
# Main RMSE: 0.5773016810417175
# Aux RMSE: 0.6297240853309631

# %%
import matplotlib.pyplot as plt
import pandas as pd

pd.DataFrame(history.history).plot(
    figsize=(8, 5), xlim=[0, 20], ylim=[0, 2], grid=True, xlabel="Epoch",
    style=["r--", "r--.", "b-", "b-*"])
plt.legend(loc="lower left")  # extra code
plt.show()

# %% [markdown]
# Note that this appears to have substantially improved things for the validation set, indicating that we indeed seem to be generalizing our data quite a bit better!

# %% [markdown]
# ## Additional Software Features
#
# Keras provides several additional software features that can be used to make the process of working with networks more useful.
#
# #### The Subclassing API
#
# The Subclassing API allows you to define custom models by subclassing the `tf.keras.Model` class. In this approach, you create a new class that inherits from `tf.keras.Model` and defines your own forward pass for the model. This method provides the greatest flexibility in defining models, as you can add loops, conditional branches, and even custom layers directly within your model.
#
# #### Why Use the Subclassing API?
#
# 1. **Custom Behavior:**
#    - If you need a model that does not fit the standard sequential or functional paradigms, subclassing enables you to implement custom behavior in the forward pass.
#
# 2. **Research and Experimentation:**
#    - For researchers experimenting with new ideas, subclassing offers a way to express complex models or layers in an intuitive manner.
#
# 3. **Dynamic Models:**
#    - Subclassing is particularly suited for dynamic models, where the architecture can change based on the input data, something that's harder to achieve with the Sequential and Functional APIs.
#
# #### How to Implement a Model using Subclassing?
#
# 1. **Define a Model Class:**
#    - Create a new class that inherits from `tf.keras.Model`.
#    - Define the layers in the `__init__` method.
#    - Implement the model's forward pass in the `call` method.
#
# 2. **Instantiate and Use the Model:**
#    - Like other Keras models, you compile and train it using `.compile()` and `.fit()` methods.
#    - It can be used for prediction with `.predict()`.
#
# #### Key Points
#
# - **Debugging:** Subclassing can make debugging easier since it works just like regular Python code.
# - **Complexity:** It's slightly more complex and error-prone than using Sequential or Functional APIs due to the lack of model validation before training.
# - **Serialization:** Subclassed models have limitations in terms of saving and loading. The structure of the model is not explicitly defined, so when saving the model, Keras saves the model's weights only.

# %%
class WideAndDeepModel(tf.keras.Model):
    def __init__(self, units=30, activation="relu", **kwargs):
        super().__init__(**kwargs)  # needed to support naming the model
        self.norm_layer_wide = tf.keras.layers.Normalization()
        self.norm_layer_deep = tf.keras.layers.Normalization()
        self.hidden1 = tf.keras.layers.Dense(units, activation=activation)
        self.hidden2 = tf.keras.layers.Dense(units, activation=activation)
        self.main_output = tf.keras.layers.Dense(1)
        self.aux_output = tf.keras.layers.Dense(1)
        
    def call(self, inputs):
        input_wide, input_deep = inputs
        norm_wide = self.norm_layer_wide(input_wide)
        norm_deep = self.norm_layer_deep(input_deep)
        hidden1 = self.hidden1(norm_deep)
        hidden2 = self.hidden2(hidden1)
        concat = tf.keras.layers.concatenate([norm_wide, hidden2])
        output = self.main_output(concat)
        aux_output = self.aux_output(hidden2)
        return output, aux_output

tf.random.set_seed(42)  # extra code – just for reproducibility
model = WideAndDeepModel(30, activation="relu", name="my_cool_model")

# %% [markdown]
# Now, to instantiate and train:

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)  # extra code – just for reproducibility
model = WideAndDeepModel(30, activation="relu", name="my_cool_model")
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="mse", loss_weights=[0.9, 0.1], optimizer=optimizer,
              metrics=["RootMeanSquaredError"])
model.norm_layer_wide.adapt(X_train_wide)
model.norm_layer_deep.adapt(X_train_deep)
history = model.fit(
    (X_train_wide, X_train_deep), (y_train, y_train), epochs=10,
    validation_data=((X_valid_wide, X_valid_deep), (y_valid, y_valid)))
eval_results = model.evaluate((X_test_wide, X_test_deep), (y_test, y_test))
weighted_sum_of_losses, main_loss, aux_loss, main_rmse, aux_rmse = eval_results
y_pred_main, y_pred_aux = model.predict((X_new_wide, X_new_deep))
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/10
# 363/363 [==============================] - 1s 1ms/step - loss: 1.8762 - output_1_loss: 1.8304 - output_2_loss: 2.2884 - output_1_root_mean_squared_error: 1.3529 - output_2_root_mean_squared_error: 1.5128 - val_loss: 1.1140 - val_output_1_loss: 0.9475 - val_output_2_loss: 2.6123 - val_output_1_root_mean_squared_error: 0.9734 - val_output_2_root_mean_squared_error: 1.6162
# Epoch 2/10
# 363/363 [==============================] - 0s 950us/step - loss: 0.6110 - output_1_loss: 0.5993 - output_2_loss: 0.7168 - output_1_root_mean_squared_error: 0.7741 - output_2_root_mean_squared_error: 0.8466 - val_loss: 1.9120 - val_output_1_loss: 1.9091 - val_output_2_loss: 1.9380 - val_output_1_root_mean_squared_error: 1.3817 - val_output_2_root_mean_squared_error: 1.3921
# Epoch 3/10
# 363/363 [==============================] - 0s 950us/step - loss: 0.5183 - output_1_loss: 0.5132 - output_2_loss: 0.5641 - output_1_root_mean_squared_error: 0.7164 - output_2_root_mean_squared_error: 0.7511 - val_loss: 0.5775 - val_output_1_loss: 0.5843 - val_output_2_loss: 0.5172 - val_output_1_root_mean_squared_error: 0.7644 - val_output_2_root_mean_squared_error: 0.7192
# Epoch 4/10
# 363/363 [==============================] - 0s 1ms/step - loss: 0.4562 - output_1_loss: 0.4496 - output_2_loss: 0.5157 - output_1_root_mean_squared_error: 0.6705 - output_2_root_mean_squared_error: 0.7181 - val_loss: 0.4204 - val_output_1_loss: 0.4083 - val_output_2_loss: 0.5292 - val_output_1_root_mean_squared_error: 0.6390 - val_output_2_root_mean_squared_error: 0.7275
# Epoch 5/10
# 363/363 [==============================] - 0s 1ms/step - loss: 0.4264 - output_1_loss: 0.4183 - output_2_loss: 0.4992 - output_1_root_mean_squared_error: 0.6467 - output_2_root_mean_squared_error: 0.7065 - val_loss: 0.9649 - val_output_1_loss: 1.0054 - val_output_2_loss: 0.6002 - val_output_1_root_mean_squared_error: 1.0027 - val_output_2_root_mean_squared_error: 0.7747
# Epoch 6/10
# 363/363 [==============================] - 0s 1ms/step - loss: 0.4056 - output_1_loss: 0.3972 - output_2_loss: 0.4807 - output_1_root_mean_squared_error: 0.6303 - output_2_root_mean_squared_error: 0.6933 - val_loss: 3.0790 - val_output_1_loss: 3.1656 - val_output_2_loss: 2.2994 - val_output_1_root_mean_squared_error: 1.7792 - val_output_2_root_mean_squared_error: 1.5164
# Epoch 7/10
# 363/363 [==============================] - 0s 943us/step - loss: 0.4069 - output_1_loss: 0.3982 - output_2_loss: 0.4854 - output_1_root_mean_squared_error: 0.6310 - output_2_root_mean_squared_error: 0.6967 - val_loss: 1.2713 - val_output_1_loss: 1.3577 - val_output_2_loss: 0.4933 - val_output_1_root_mean_squared_error: 1.1652 - val_output_2_root_mean_squared_error: 0.7024
# Epoch 8/10
# 363/363 [==============================] - 0s 950us/step - loss: 0.3736 - output_1_loss: 0.3646 - output_2_loss: 0.4547 - output_1_root_mean_squared_error: 0.6038 - output_2_root_mean_squared_error: 0.6743 - val_loss: 2.6390 - val_output_1_loss: 2.8482 - val_output_2_loss: 0.7560 - val_output_1_root_mean_squared_error: 1.6877 - val_output_2_root_mean_squared_error: 0.8695
# Epoch 9/10
# 363/363 [==============================] - 0s 957us/step - loss: 0.3718 - output_1_loss: 0.3639 - output_2_loss: 0.4429 - output_1_root_mean_squared_error: 0.6032 - output_2_root_mean_squared_error: 0.6655 - val_loss: 2.2803 - val_output_1_loss: 2.4612 - val_output_2_loss: 0.6528 - val_output_1_root_mean_squared_error: 1.5688 - val_output_2_root_mean_squared_error: 0.8079
# Epoch 10/10
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3807 - output_1_loss: 0.3746 - output_2_loss: 0.4362 - output_1_root_mean_squared_error: 0.6120 - output_2_root_mean_squared_error: 0.6605 - val_loss: 3.3913 - val_output_1_loss: 3.5521 - val_output_2_loss: 1.9448 - val_output_1_root_mean_squared_error: 1.8847 - val_output_2_root_mean_squared_error: 1.3946
# 162/162 [==============================] - 0s 640us/step - loss: 0.3648 - output_1_loss: 0.3576 - output_2_loss: 0.4288 - output_1_root_mean_squared_error: 0.5980 - output_2_root_mean_squared_error: 0.6549
# 1/1 [==============================] - 0s 54ms/step

# %% [markdown]
# ## Saving and restoring models

# %% [markdown]
# Models can be easily saved off for future use with:

# %%
model.save("my_keras_model", save_format="tf")
# Out:
# INFO:tensorflow:Assets written to: my_keras_model/assets
# INFO:tensorflow:Assets written to: my_keras_model/assets

# %% [markdown]
# All aspects of the model are saved this way, including weights and any hyperparameters.  Loading the model can be easily accomplished with:

# %%
model = tf.keras.models.load_model("my_keras_model")
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.RestoredOptimizer` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.RestoredOptimizer`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# You can also save and load just the weights for a network, which is faster uses less disk space then storing the entire model.  This is useful when saving "checkpoints" during the model training process.  Checkpoints provide a restore point if something goes awry during the training process.  To accomplish this, we use callbacks, described below.

# %% [markdown]
# ### Using Callbacks
#
# Sometimes it is useful to interrupt the training process to inspect aspects of the network. The `fit()` methods accepts a set of functions (referred to as callbacks) which can be run during the training process.  There are three places when you can run callback functions:
# - Before and after training
# - Before and after each epoch
# - Before and after each batch
#
# Keras offers a number of [pre-built callbacks](https://keras.io/api/callbacks/) and you [can write your own](https://keras.io/guides/writing_your_own_callbacks/) if you want.
#
# #### Examples
#
# **Model Checkpoints**
#
# The ModelCheckpoint callback allows you to save checkpoints at regular intervals during training.  This can be useful both for inspection, and as a backup mechanism in case something goes wrong during training. This is also a nice way to avoid overtraining with too many epochs, since it is easy to roll back to a previous training state.
#
# ~~~python
# checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("my_checkpoints", save_weights_only=True)
# history = model.fit([...], callbacks=[checkpoint_cb])
# ~~~
#
# **Early Stopping**
#
# The `EarlyStopping` callback allows you to interrupt training when no progress is made on the validation step for a number of epochs.  Setting `restore_best_weights=True` will roll back to the best model at the end of training.
#
# ~~~python
# early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,restore_best_weights=True)
# history = model.fit([...], callbacks=[checkpoint_cb, early_stopping_cb])
# ~~~

# %% [markdown]
# ### Using Tensorboard
#
# Tensorflow provides a UI called Tensorboard for inspecting the performance of training.  To use Tensorboard, we need to log data in a special format using the Tensorboard callback.  Generally, speaking, it's useful to organize log data with a single top level directory for all logging (you might want to add this to your `.gitignore` file) and then create logs for different runs in subdirectories.  The following code takes care of creating the path where logs should reside.

# %%
from pathlib import Path 
from time import strftime
def get_run_logdir(root_logdir="./logs"):
    return Path(root_logdir) / strftime("run_%Y_%m_%d_%H_%M_%S")


get_run_logdir()
# Out:
# PosixPath('logs/run_2024_04_01_18_24_54')

# %% [markdown]
# To use Tensorboard, all we need is to install the callback when we train the model.  First, set up the model (we'll use the subclassed version above):

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)  # extra code – just for reproducibility
model = WideAndDeepModel(30, activation="relu", name="my_cool_model")
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="mse", loss_weights=[0.9, 0.1], optimizer=optimizer,
              metrics=["RootMeanSquaredError"])
model.norm_layer_wide.adapt(X_train_wide)
model.norm_layer_deep.adapt(X_train_deep)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# Then, we'll add the tensorboard callback and train.

# %%
test_dir = get_run_logdir()
tensorboard_cb = tf.keras.callbacks.TensorBoard(test_dir, profile_batch=(100, 200))
history=model.fit(
    (X_train_wide, X_train_deep), (y_train, y_train), epochs=20,
    validation_data=((X_valid_wide, X_valid_deep), (y_valid, y_valid)),callbacks=[tensorboard_cb])
# Out:
# Epoch 1/20
# 2024-04-01 18:24:54.974406: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:104] Profiler session initializing.
# 2024-04-01 18:24:54.974421: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:119] Profiler session started.
# 2024-04-01 18:24:54.974786: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:131] Profiler session tear down.
# 252/363 [===================>..........] - ETA: 0s - loss: 1.6693 - output_1_loss: 1.5639 - output_2_loss: 2.6181 - output_1_root_mean_squared_error: 1.2506 - output_2_root_mean_squared_error: 1.6180
# 2024-04-01 18:24:55.788073: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:104] Profiler session initializing.
# 2024-04-01 18:24:55.788089: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:119] Profiler session started.
# 2024-04-01 18:24:55.895296: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:70] Profiler session collecting data.
# 2024-04-01 18:24:55.913786: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:131] Profiler session tear down.
# 2024-04-01 18:24:55.915793: I external/local_tsl/tsl/profiler/rpc/client/save_profile.cc:144] Collecting XSpace to repository: logs/run_2024_04_01_18_24_54/plugins/profile/2024_04_01_18_24_55/tianhangdeAir.lan.xplane.pb
# 363/363 [==============================] - 1s 2ms/step - loss: 1.3550 - output_1_loss: 1.2716 - output_2_loss: 2.1064 - output_1_root_mean_squared_error: 1.1276 - output_2_root_mean_squared_error: 1.4514 - val_loss: 2.4673 - val_output_1_loss: 1.1308 - val_output_2_loss: 14.4951 - val_output_1_root_mean_squared_error: 1.0634 - val_output_2_root_mean_squared_error: 3.8072
# Epoch 2/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.5354 - output_1_loss: 0.5036 - output_2_loss: 0.8216 - output_1_root_mean_squared_error: 0.7097 - output_2_root_mean_squared_error: 0.9064 - val_loss: 1.3109 - val_output_1_loss: 0.6977 - val_output_2_loss: 6.8302 - val_output_1_root_mean_squared_error: 0.8353 - val_output_2_root_mean_squared_error: 2.6135
# Epoch 3/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.4673 - output_1_loss: 0.4470 - output_2_loss: 0.6504 - output_1_root_mean_squared_error: 0.6685 - output_2_root_mean_squared_error: 0.8065 - val_loss: 0.6366 - val_output_1_loss: 0.4283 - val_output_2_loss: 2.5109 - val_output_1_root_mean_squared_error: 0.6545 - val_output_2_root_mean_squared_error: 1.5846
# Epoch 4/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.4364 - output_1_loss: 0.4200 - output_2_loss: 0.5843 - output_1_root_mean_squared_error: 0.6481 - output_2_root_mean_squared_error: 0.7644 - val_loss: 0.5214 - val_output_1_loss: 0.4861 - val_output_2_loss: 0.8386 - val_output_1_root_mean_squared_error: 0.6972 - val_output_2_root_mean_squared_error: 0.9158
# Epoch 5/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4168 - output_1_loss: 0.4020 - output_2_loss: 0.5498 - output_1_root_mean_squared_error: 0.6341 - output_2_root_mean_squared_error: 0.7415 - val_loss: 0.3831 - val_output_1_loss: 0.3653 - val_output_2_loss: 0.5432 - val_output_1_root_mean_squared_error: 0.6044 - val_output_2_root_mean_squared_error: 0.7370
# Epoch 6/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3971 - output_1_loss: 0.3829 - output_2_loss: 0.5246 - output_1_root_mean_squared_error: 0.6188 - output_2_root_mean_squared_error: 0.7243 - val_loss: 0.3906 - val_output_1_loss: 0.3683 - val_output_2_loss: 0.5918 - val_output_1_root_mean_squared_error: 0.6069 - val_output_2_root_mean_squared_error: 0.7693
# Epoch 7/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3868 - output_1_loss: 0.3740 - output_2_loss: 0.5022 - output_1_root_mean_squared_error: 0.6115 - output_2_root_mean_squared_error: 0.7086 - val_loss: 0.5148 - val_output_1_loss: 0.5196 - val_output_2_loss: 0.4714 - val_output_1_root_mean_squared_error: 0.7208 - val_output_2_root_mean_squared_error: 0.6866
# Epoch 8/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3771 - output_1_loss: 0.3654 - output_2_loss: 0.4831 - output_1_root_mean_squared_error: 0.6044 - output_2_root_mean_squared_error: 0.6951 - val_loss: 1.5297 - val_output_1_loss: 1.6169 - val_output_2_loss: 0.7454 - val_output_1_root_mean_squared_error: 1.2716 - val_output_2_root_mean_squared_error: 0.8634
# Epoch 9/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3727 - output_1_loss: 0.3624 - output_2_loss: 0.4653 - output_1_root_mean_squared_error: 0.6020 - output_2_root_mean_squared_error: 0.6821 - val_loss: 2.7191 - val_output_1_loss: 2.9516 - val_output_2_loss: 0.6261 - val_output_1_root_mean_squared_error: 1.7180 - val_output_2_root_mean_squared_error: 0.7913
# Epoch 10/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3873 - output_1_loss: 0.3797 - output_2_loss: 0.4554 - output_1_root_mean_squared_error: 0.6162 - output_2_root_mean_squared_error: 0.6748 - val_loss: 2.3817 - val_output_1_loss: 2.5237 - val_output_2_loss: 1.1039 - val_output_1_root_mean_squared_error: 1.5886 - val_output_2_root_mean_squared_error: 1.0506
# Epoch 11/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3694 - output_1_loss: 0.3609 - output_2_loss: 0.4458 - output_1_root_mean_squared_error: 0.6007 - output_2_root_mean_squared_error: 0.6677 - val_loss: 0.4963 - val_output_1_loss: 0.5055 - val_output_2_loss: 0.4137 - val_output_1_root_mean_squared_error: 0.7110 - val_output_2_root_mean_squared_error: 0.6432
# Epoch 12/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3717 - output_1_loss: 0.3642 - output_2_loss: 0.4395 - output_1_root_mean_squared_error: 0.6035 - output_2_root_mean_squared_error: 0.6630 - val_loss: 0.8546 - val_output_1_loss: 0.8742 - val_output_2_loss: 0.6783 - val_output_1_root_mean_squared_error: 0.9350 - val_output_2_root_mean_squared_error: 0.8236
# Epoch 13/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3564 - output_1_loss: 0.3485 - output_2_loss: 0.4271 - output_1_root_mean_squared_error: 0.5904 - output_2_root_mean_squared_error: 0.6535 - val_loss: 0.4641 - val_output_1_loss: 0.4702 - val_output_2_loss: 0.4088 - val_output_1_root_mean_squared_error: 0.6857 - val_output_2_root_mean_squared_error: 0.6394
# Epoch 14/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3537 - output_1_loss: 0.3455 - output_2_loss: 0.4273 - output_1_root_mean_squared_error: 0.5878 - output_2_root_mean_squared_error: 0.6537 - val_loss: 0.7059 - val_output_1_loss: 0.7169 - val_output_2_loss: 0.6072 - val_output_1_root_mean_squared_error: 0.8467 - val_output_2_root_mean_squared_error: 0.7792
# Epoch 15/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3486 - output_1_loss: 0.3414 - output_2_loss: 0.4138 - output_1_root_mean_squared_error: 0.5843 - output_2_root_mean_squared_error: 0.6432 - val_loss: 1.1582 - val_output_1_loss: 1.2039 - val_output_2_loss: 0.7472 - val_output_1_root_mean_squared_error: 1.0972 - val_output_2_root_mean_squared_error: 0.8644
# Epoch 16/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3502 - output_1_loss: 0.3430 - output_2_loss: 0.4152 - output_1_root_mean_squared_error: 0.5856 - output_2_root_mean_squared_error: 0.6443 - val_loss: 1.7604 - val_output_1_loss: 1.7878 - val_output_2_loss: 1.5133 - val_output_1_root_mean_squared_error: 1.3371 - val_output_2_root_mean_squared_error: 1.2302
# Epoch 17/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3555 - output_1_loss: 0.3487 - output_2_loss: 0.4159 - output_1_root_mean_squared_error: 0.5905 - output_2_root_mean_squared_error: 0.6449 - val_loss: 1.9583 - val_output_1_loss: 2.0367 - val_output_2_loss: 1.2527 - val_output_1_root_mean_squared_error: 1.4271 - val_output_2_root_mean_squared_error: 1.1192
# Epoch 18/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3510 - output_1_loss: 0.3446 - output_2_loss: 0.4082 - output_1_root_mean_squared_error: 0.5870 - output_2_root_mean_squared_error: 0.6389 - val_loss: 2.8597 - val_output_1_loss: 3.0207 - val_output_2_loss: 1.4112 - val_output_1_root_mean_squared_error: 1.7380 - val_output_2_root_mean_squared_error: 1.1879
# Epoch 19/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3583 - output_1_loss: 0.3524 - output_2_loss: 0.4114 - output_1_root_mean_squared_error: 0.5936 - output_2_root_mean_squared_error: 0.6414 - val_loss: 1.3750 - val_output_1_loss: 1.4836 - val_output_2_loss: 0.3968 - val_output_1_root_mean_squared_error: 1.2180 - val_output_2_root_mean_squared_error: 0.6299
# Epoch 20/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3477 - output_1_loss: 0.3420 - output_2_loss: 0.3988 - output_1_root_mean_squared_error: 0.5848 - output_2_root_mean_squared_error: 0.6315 - val_loss: 0.8819 - val_output_1_loss: 0.9221 - val_output_2_loss: 0.5208 - val_output_1_root_mean_squared_error: 0.9602 - val_output_2_root_mean_squared_error: 0.7217

# %% [markdown]
# Now, for comparison's sake, we'll run the model again with a slightly higher learning rate.

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)  # extra code – just for reproducibility
model = WideAndDeepModel(30, activation="relu", name="my_cool_model")

# Doubled the learning
optimizer = tf.keras.optimizers.Adam(learning_rate=2e-3)
model.compile(loss="mse", loss_weights=[0.9, 0.1], optimizer=optimizer,
              metrics=["RootMeanSquaredError"])
model.norm_layer_wide.adapt(X_train_wide)
model.norm_layer_deep.adapt(X_train_deep)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %%
test_dir = get_run_logdir()
tensorboard_cb = tf.keras.callbacks.TensorBoard(test_dir, profile_batch=(100, 200))
history=model.fit(
    (X_train_wide, X_train_deep), (y_train, y_train), epochs=20,
    validation_data=((X_valid_wide, X_valid_deep), (y_valid, y_valid)),callbacks=[tensorboard_cb])
# Out:
# Epoch 1/20
# 2024-04-01 18:25:06.423368: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:104] Profiler session initializing.
# 2024-04-01 18:25:06.423378: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:119] Profiler session started.
# 2024-04-01 18:25:06.423704: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:131] Profiler session tear down.
# 200/363 [===============>..............] - ETA: 0s - loss: 1.9208 - output_1_loss: 1.9256 - output_2_loss: 1.8781 - output_1_root_mean_squared_error: 1.3876 - output_2_root_mean_squared_error: 1.3704
# 2024-04-01 18:25:07.144971: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:104] Profiler session initializing.
# 2024-04-01 18:25:07.144989: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:119] Profiler session started.
# 2024-04-01 18:25:07.275851: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:70] Profiler session collecting data.
# 2024-04-01 18:25:07.293537: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:131] Profiler session tear down.
# 2024-04-01 18:25:07.294022: I external/local_tsl/tsl/profiler/rpc/client/save_profile.cc:144] Collecting XSpace to repository: logs/run_2024_04_01_18_25_06/plugins/profile/2024_04_01_18_25_07/tianhangdeAir.lan.xplane.pb
# 363/363 [==============================] - 1s 2ms/step - loss: 1.3350 - output_1_loss: 1.3334 - output_2_loss: 1.3496 - output_1_root_mean_squared_error: 1.1547 - output_2_root_mean_squared_error: 1.1617 - val_loss: 1.3179 - val_output_1_loss: 1.3526 - val_output_2_loss: 1.0052 - val_output_1_root_mean_squared_error: 1.1630 - val_output_2_root_mean_squared_error: 1.0026
# Epoch 2/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.4898 - output_1_loss: 0.4802 - output_2_loss: 0.5761 - output_1_root_mean_squared_error: 0.6930 - output_2_root_mean_squared_error: 0.7590 - val_loss: 1.5880 - val_output_1_loss: 1.5943 - val_output_2_loss: 1.5319 - val_output_1_root_mean_squared_error: 1.2626 - val_output_2_root_mean_squared_error: 1.2377
# Epoch 3/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.4284 - output_1_loss: 0.4178 - output_2_loss: 0.5238 - output_1_root_mean_squared_error: 0.6463 - output_2_root_mean_squared_error: 0.7237 - val_loss: 0.3796 - val_output_1_loss: 0.3681 - val_output_2_loss: 0.4836 - val_output_1_root_mean_squared_error: 0.6067 - val_output_2_root_mean_squared_error: 0.6954
# Epoch 4/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3929 - output_1_loss: 0.3821 - output_2_loss: 0.4902 - output_1_root_mean_squared_error: 0.6181 - output_2_root_mean_squared_error: 0.7001 - val_loss: 0.3615 - val_output_1_loss: 0.3516 - val_output_2_loss: 0.4498 - val_output_1_root_mean_squared_error: 0.5930 - val_output_2_root_mean_squared_error: 0.6706
# Epoch 5/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3755 - output_1_loss: 0.3653 - output_2_loss: 0.4671 - output_1_root_mean_squared_error: 0.6044 - output_2_root_mean_squared_error: 0.6835 - val_loss: 0.5555 - val_output_1_loss: 0.5588 - val_output_2_loss: 0.5264 - val_output_1_root_mean_squared_error: 0.7475 - val_output_2_root_mean_squared_error: 0.7255
# Epoch 6/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3670 - output_1_loss: 0.3579 - output_2_loss: 0.4489 - output_1_root_mean_squared_error: 0.5983 - output_2_root_mean_squared_error: 0.6700 - val_loss: 0.5523 - val_output_1_loss: 0.5617 - val_output_2_loss: 0.4681 - val_output_1_root_mean_squared_error: 0.7495 - val_output_2_root_mean_squared_error: 0.6842
# Epoch 7/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3623 - output_1_loss: 0.3541 - output_2_loss: 0.4368 - output_1_root_mean_squared_error: 0.5950 - output_2_root_mean_squared_error: 0.6609 - val_loss: 1.2382 - val_output_1_loss: 1.2391 - val_output_2_loss: 1.2306 - val_output_1_root_mean_squared_error: 1.1131 - val_output_2_root_mean_squared_error: 1.1093
# Epoch 8/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3562 - output_1_loss: 0.3486 - output_2_loss: 0.4246 - output_1_root_mean_squared_error: 0.5904 - output_2_root_mean_squared_error: 0.6516 - val_loss: 1.7124 - val_output_1_loss: 1.8141 - val_output_2_loss: 0.7969 - val_output_1_root_mean_squared_error: 1.3469 - val_output_2_root_mean_squared_error: 0.8927
# Epoch 9/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3569 - output_1_loss: 0.3499 - output_2_loss: 0.4191 - output_1_root_mean_squared_error: 0.5916 - output_2_root_mean_squared_error: 0.6474 - val_loss: 3.8512 - val_output_1_loss: 3.9860 - val_output_2_loss: 2.6385 - val_output_1_root_mean_squared_error: 1.9965 - val_output_2_root_mean_squared_error: 1.6244
# Epoch 10/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3850 - output_1_loss: 0.3791 - output_2_loss: 0.4373 - output_1_root_mean_squared_error: 0.6157 - output_2_root_mean_squared_error: 0.6613 - val_loss: 1.1352 - val_output_1_loss: 1.1836 - val_output_2_loss: 0.6989 - val_output_1_root_mean_squared_error: 1.0880 - val_output_2_root_mean_squared_error: 0.8360
# Epoch 11/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3435 - output_1_loss: 0.3367 - output_2_loss: 0.4046 - output_1_root_mean_squared_error: 0.5802 - output_2_root_mean_squared_error: 0.6361 - val_loss: 1.4380 - val_output_1_loss: 1.3085 - val_output_2_loss: 2.6037 - val_output_1_root_mean_squared_error: 1.1439 - val_output_2_root_mean_squared_error: 1.6136
# Epoch 12/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3663 - output_1_loss: 0.3581 - output_2_loss: 0.4403 - output_1_root_mean_squared_error: 0.5984 - output_2_root_mean_squared_error: 0.6636 - val_loss: 0.7285 - val_output_1_loss: 0.7164 - val_output_2_loss: 0.8373 - val_output_1_root_mean_squared_error: 0.8464 - val_output_2_root_mean_squared_error: 0.9151
# Epoch 13/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3436 - output_1_loss: 0.3368 - output_2_loss: 0.4052 - output_1_root_mean_squared_error: 0.5803 - output_2_root_mean_squared_error: 0.6366 - val_loss: 0.7820 - val_output_1_loss: 0.7779 - val_output_2_loss: 0.8194 - val_output_1_root_mean_squared_error: 0.8820 - val_output_2_root_mean_squared_error: 0.9052
# Epoch 14/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3410 - output_1_loss: 0.3348 - output_2_loss: 0.3967 - output_1_root_mean_squared_error: 0.5786 - output_2_root_mean_squared_error: 0.6298 - val_loss: 0.5468 - val_output_1_loss: 0.5611 - val_output_2_loss: 0.4183 - val_output_1_root_mean_squared_error: 0.7491 - val_output_2_root_mean_squared_error: 0.6468
# Epoch 15/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3395 - output_1_loss: 0.3330 - output_2_loss: 0.3979 - output_1_root_mean_squared_error: 0.5771 - output_2_root_mean_squared_error: 0.6308 - val_loss: 0.4535 - val_output_1_loss: 0.4454 - val_output_2_loss: 0.5271 - val_output_1_root_mean_squared_error: 0.6674 - val_output_2_root_mean_squared_error: 0.7260
# Epoch 16/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3351 - output_1_loss: 0.3288 - output_2_loss: 0.3919 - output_1_root_mean_squared_error: 0.5734 - output_2_root_mean_squared_error: 0.6261 - val_loss: 0.4009 - val_output_1_loss: 0.4024 - val_output_2_loss: 0.3878 - val_output_1_root_mean_squared_error: 0.6343 - val_output_2_root_mean_squared_error: 0.6228
# Epoch 17/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3351 - output_1_loss: 0.3287 - output_2_loss: 0.3922 - output_1_root_mean_squared_error: 0.5734 - output_2_root_mean_squared_error: 0.6263 - val_loss: 0.4388 - val_output_1_loss: 0.4274 - val_output_2_loss: 0.5414 - val_output_1_root_mean_squared_error: 0.6537 - val_output_2_root_mean_squared_error: 0.7358
# Epoch 18/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3280 - output_1_loss: 0.3221 - output_2_loss: 0.3810 - output_1_root_mean_squared_error: 0.5676 - output_2_root_mean_squared_error: 0.6173 - val_loss: 0.3215 - val_output_1_loss: 0.3108 - val_output_2_loss: 0.4172 - val_output_1_root_mean_squared_error: 0.5575 - val_output_2_root_mean_squared_error: 0.6459
# Epoch 19/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3255 - output_1_loss: 0.3198 - output_2_loss: 0.3775 - output_1_root_mean_squared_error: 0.5655 - output_2_root_mean_squared_error: 0.6144 - val_loss: 0.3211 - val_output_1_loss: 0.3118 - val_output_2_loss: 0.4054 - val_output_1_root_mean_squared_error: 0.5584 - val_output_2_root_mean_squared_error: 0.6367
# Epoch 20/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3289 - output_1_loss: 0.3233 - output_2_loss: 0.3799 - output_1_root_mean_squared_error: 0.5686 - output_2_root_mean_squared_error: 0.6164 - val_loss: 0.3876 - val_output_1_loss: 0.3840 - val_output_2_loss: 0.4192 - val_output_1_root_mean_squared_error: 0.6197 - val_output_2_root_mean_squared_error: 0.6474

# %% [markdown]
# Now we can start up `tensorboard` to have a look at our log files.  Once tensorboard is running, you can browse to http://localhost:6006/ to have a look.

# %%
# %load_ext tensorboard 
# %tensorboard --logdir=./logs
# Out:
#       <iframe id="tensorboard-frame-a65a92709f269ece" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a65a92709f269ece");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# Tensorboard is a highly functional tool, and has some neat functions for visualizing high dimensional embedding spaces within a network.  You can read more about this ![here](https://www.tensorflow.org/tensorboard/tensorboard_projector_plugin).
